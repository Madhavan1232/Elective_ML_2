# %%
import numpy as np, pandas as pd
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
np.random.seed(5)
n=200
X1 = np.random.normal(50,10,n)
X2 = X1*0.8 + np.random.normal(0,5,n)  # correlated
X3 = np.random.normal(100,30,n)
y = 2 + 0.5*X1 - 0.3*X3 + np.random.normal(0,5,n)
df = pd.DataFrame({'X1':X1,'X2':X2,'X3':X3,'y':y})
X = df[['X1','X2','X3']]; X_const = sm.add_constant(X)
vifs = pd.DataFrame({'feature': X.columns, 'VIF':[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]})
print(vifs)
model = sm.OLS(df['y'], X_const).fit()
print(model.summary().tables[0])
print('Adjusted R2=', model.rsquared_adj)
# Out:
#   feature        VIF
# 0      X1  77.152110
# 1      X2  71.092253
# 2      X3   9.036722
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.793
# Method:                 Least Squares   F-statistic:                     255.9
# Date:                Wed, 26 Nov 2025   Prob (F-statistic):           1.65e-67
# Time:                        04:01:56   Log-Likelihood:                -602.06
# No. Observations:                 200   AIC:                             1212.
# Df Residuals:                     196   BIC:                             1225.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
# Adjusted R2= 0.7934949943505873
