# %%
from scipy.stats import chi2_contingency


table = [[20 , 30] ,
          [25 , 20]]
stat, p, dof, expected = chi2_contingency(table)

print(f"Chi-square Statistic: {stat}, p-value: {p}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies: {expected}")

if p < 0.05:
    print("Have relationship between gender and study method")
else:
    print("Do not have relationship between gender and study method")
# Out:
# Chi-square Statistic: 1.7171543209876559, p-value: 0.19005975878910525
# Degrees of Freedom: 1
# Expected Frequencies: [[23.68421053 26.31578947]
#  [21.31578947 23.68421053]]
# Do not have relationship between gender and study method
